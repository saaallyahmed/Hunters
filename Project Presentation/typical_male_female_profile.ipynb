# %%
import pandas as pd

# %%
# Raw data file
file_to_load = "../Resources/profiles_revised_Mar_29.csv"

# Read purchasing file and store into pandas data frame
df= pd.read_csv(file_to_load)
df.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially        NaN
# 3   22            thin         vegetarian  socially        NaN
# 4   30        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job                               offspring  \
# ...

# %%
df1=df.groupby(['sex'])

# %%
df1.head()
# Out:
#     age       body_type               diet    drinks      drugs  \
# 0    22  a little extra  strictly anything  socially      never
# 1    36         average       mostly other     often  sometimes
# 2    37            thin           anything  socially        NaN
# 3    22            thin         vegetarian  socially        NaN
# 4    30        athletic                NaN  socially      never
# 6    32             fit  strictly anything  socially      never
# 7    30         average    mostly anything  socially      never
# 8    25             NaN  strictly anything  socially        NaN
# 13   29          skinny    mostly anything  socially      never
# 14   29            thin    mostly anything  socially      never
#
#                             education                ethnicity  height  \
# 0       working on college/university             asian, white    75.0
# 1               working on space camp                    white    70.0
# ...

# %%
age=df1['age'].value_counts()
df=pd.set_option("display.max_rows", None)
print(age)
# Out:
# sex  age
# f    27     1380
#      26     1362
#      25     1345
#      29     1258
#      28     1251
#      24     1196
#      30     1176
#      31     1068
#      23     1048
#      32     1018
#      33      906
#      22      851
#      34      841
#      35      704
#      36      654
#      21      572
#      37      550
#      38      521
#      39      508
#      40      420
#      20      418
#      41      418
#      43      394
#      42      383
#      44      289
#      19      287
#      45      263
#      46      241
#      47      205
#      48      205
#      49      190
#      50      185
#      51      172
#      52      151
#      18      146
#      56      146
#      53      138
#      54      126
#      55      125
#      57      117
#      61      117
#      58      105
#      59       97
#      60       97
#      62       83
#      63       71
#      65       64
#      66       62
#      64       60
#      17       52
#      67       41
#      68       24
# ...

# %%
df1['body_type'].value_counts()
# Out:
# sex  body_type
# f    average           5620
#      fit               4431
#      curvy             3811
#      thin              2469
#      athletic          2309
#      full figured       870
#      a little extra     821
#      skinny             601
#      overweight         145
#      jacked             129
#      rather not say     106
#      used up            102
# m    athletic          9510
#      average           9032
#      fit               8280
#      thin              2242
#      a little extra    1808
#      skinny            1176
#      overweight         299
#      jacked             292
#      used up            253
#      full figured       139
#      curvy              113
#      rather not say      92
# Name: body_type, dtype: int64

# %%
df1['diet'].value_counts()
# Out:
# sex  diet
# f    mostly anything         6358
#      anything                2417
#      mostly vegetarian       1913
#      strictly anything       1479
#      strictly vegetarian      469
#      mostly other             425
#      vegetarian               378
#      mostly vegan             181
#      strictly other           178
#      other                    164
#      strictly vegan           107
#      vegan                     71
#      mostly kosher             36
#      mostly halal              12
#      kosher                     6
#      strictly kosher            5
#      halal                      3
#      strictly halal             2
# m    mostly anything        10227
#      anything                3766
#      strictly anything       3634
#      mostly vegetarian       1531
#      mostly other             582
#      strictly vegetarian      406
#      vegetarian               289
#      strictly other           274
#      other                    167
# ...

# %%
df1['drinks'].value_counts()
# Out:
# sex  drinks
# f    socially       17223
#      rarely          2408
#      often           1850
#      not at all      1233
#      very often       177
#      desperately      114
# m    socially       24557
#      rarely          3549
#      often           3314
#      not at all      2034
#      very often       294
#      desperately      208
# Name: drinks, dtype: int64

# %%
df1['drugs'].value_counts()
# Out:
# sex  drugs
# f    never        15829
#      sometimes     2695
#      often          128
# m    never        21895
#      sometimes     5037
#      often          282
# Name: drugs, dtype: int64

# %%
edu=df1['education'].value_counts()
df=pd.set_option("display.max_rows", None)
print(edu)
# Out:
# sex  education
# f    graduated from college/university     9843
#      graduated from masters program        4263
#      working on college/university         2395
#      working on masters program             864
#      graduated from two-year college        544
#      graduated from law school              508
#      graduated from ph.d program            421
#      graduated from high school             408
#      working on two-year college            359
#      working on ph.d program                339
#      college/university                     281
#      dropped out of college/university      223
#      graduated from med school              207
#      graduated from space camp              202
#      working on space camp                  137
#      dropped out of space camp              129
#      working on law school                  119
#      working on med school                  100
#      two-year college                        69
# ...

# %%
ethn=df1['ethnicity'].value_counts()
df=pd.set_option("display.max_rows", None)
print(ethn)
# Out:
# sex  ethnicity
# f    white                                                                                                      13428
#      asian                                                                                                       2469
#      hispanic / latin                                                                                            1006
#      black                                                                                                        882
#      other                                                                                                        696
#      hispanic / latin, white                                                                                      524
#      asian, white                                                                                                 330
#      indian                                                                                                       290
# ...

# %%
height=df1['height'].value_counts()
df=pd.set_option("display.max_rows", None)
print(height)
# Out:
# sex  height
# f    64.0      3484
#      66.0      3180
#      65.0      3085
#      67.0      2786
#      63.0      2631
#      62.0      2189
#      68.0      1959
#      69.0      1225
#      61.0      1064
#      70.0       779
#      60.0       760
#      71.0       373
#      59.0       209
#      72.0       194
#      73.0        53
#      58.0        49
#      74.0        23
#      57.0        17
#      75.0         8
#      56.0         7
#      55.0         5
#      76.0         5
#      95.0         5
#      77.0         4
#      36.0         2
#      48.0         2
#      53.0         2
#      54.0         2
#      4.0          1
#      6.0          1
#      8.0          1
#      37.0         1
#      42.0         1
#      43.0         1
#      51.0         1
#      52.0         1
#      84.0         1
#      87.0         1
#      91.0         1
#      92.0         1
#      93.0         1
#      94.0         1
# m    70.0      5295
#      72.0      5121
# ...

# %%
df1['income'].value_counts()
# Out:
# sex  income
# f    -1          21004
#       20000       1031
#       40000        339
#       30000        320
#       50000        311
#       80000        261
#       100000       256
#       60000        221
#       70000        166
#       1000000      125
#       150000        75
#       250000         5
#       500000         3
# m    -1          27438
#       20000       1921
#       100000      1365
#       80000        850
#       30000        728
#       40000        666
#       50000        664
#       150000       556
#       70000        541
#       60000        515
#       1000000      396
#       250000       144
#       500000        45
# Name: income, dtype: int64

# %%
df1['job'].value_counts()
# Out:
# sex  job
# f    other                                3644
#      medicine / health                    2187
#      education / academia                 2155
#      student                              2151
#      sales / marketing / biz dev          1916
#      artistic / musical / writer          1882
#      science / tech / engineering         1016
#      banking / financial / real estate     790
#      executive / management                755
#      entertainment / media                 681
#      computer / hardware / software        641
#      law / legal services                  640
#      clerical / administrative             572
#      hospitality / travel                  570
#      political / government                310
#      rather not say                        171
#      unemployed                            113
#      retired                               106
#      construction / craftsmanship           81
#      transportation                         58
# ...

# %%
df1['offspring'].value_counts()
# Out:
# sex  offspring
# f    doesn't have kids                          3125
#      doesn't have kids, but wants them          1840
#      doesn't have kids, but might want them     1506
#      doesn't want kids                          1177
#      has a kid                                   997
#      has kids                                    943
#      doesn't have kids, and doesn't want any     508
#      has kids, but doesn't want more             255
#      has a kid, but doesn't want more            178
#      wants kids                                  131
#      has a kid, and might want more               90
#      might want kids                              62
#      has kids, and might want more                46
#      has a kid, and wants more                    26
#      has kids, and wants more                      8
# m    doesn't have kids                          4435
#      doesn't have kids, but might want them     2369
# ...

# %%
df1['orientation'].value_counts()
# Out:
# sex  orientation
# f    straight       20533
#      bisexual        1996
#      gay             1588
# m    straight       31073
#      gay             3985
#      bisexual         771
# Name: orientation, dtype: int64

# %%
df1['pets'].value_counts()
# Out:
# sex  pets
# f    likes dogs and likes cats          5264
#      likes dogs                         2700
#      likes dogs and has cats            2585
#      has dogs                           1967
#      has dogs and likes cats            1150
#      likes dogs and dislikes cats        918
#      has dogs and has cats               897
#      has cats                            795
#      likes cats                          347
#      has dogs and dislikes cats          314
#      dislikes dogs and dislikes cats      95
#      dislikes dogs and likes cats         75
#      dislikes cats                        58
#      dislikes dogs and has cats           32
#      dislikes dogs                        22
# m    likes dogs and likes cats          9550
#      likes dogs                         4524
#      has dogs                           2167
#      likes dogs and has cats            1728
#      has dogs and likes cats            1183
#      likes dogs and dislikes cats       1111
# ...

# %%
religion=df1['religion'].value_counts()
df=pd.set_option("display.max_rows", None)
print(religion)
# Out:
# sex  religion
# f    other                                         1318
#      agnosticism                                   1154
#      catholicism but not too serious about it      1011
#      agnosticism but not too serious about it       968
#      christianity                                   958
#      agnosticism and laughing about it              808
#      christianity but not too serious about it      795
#      other and laughing about it                    786
#      judaism but not too serious about it           748
#      atheism                                        674
#      other but not too serious about it             614
#      atheism and laughing about it                  533
#      catholicism                                    458
#      christianity and somewhat serious about it     455
#      other and somewhat serious about it            429
#      atheism but not too serious about it           335
# ...

# %%
df1['sex'].value_counts()
# Out:
# sex  sex
# f    f      24117
# m    m      35829
# Name: sex, dtype: int64

# %%
sign=df1['sign'].value_counts()
df=pd.set_option("display.max_rows", None)
print(sign)
# Out:
# sex  sign
# f    gemini and it's fun to think about         860
#      leo and it's fun to think about            841
#      sagittarius and it's fun to think about    816
#      scorpio and it's fun to think about        809
#      taurus and it's fun to think about         804
#      virgo and it's fun to think about          794
#      libra and it's fun to think about          787
#      aries and it's fun to think about          785
#      pisces and it's fun to think about         783
#      aquarius and it's fun to think about       764
#      cancer and it's fun to think about         761
#      capricorn and it's fun to think about      712
#      virgo but it doesn't matter                511
#      gemini but it doesn't matter               496
#      sagittarius but it doesn't matter          495
#      cancer but it doesn't matter               487
#      taurus but it doesn't matter               483
#      leo but it doesn't matter                  472
# ...

# %%
df1['smokes'].value_counts()
# Out:
# sex  smokes
# f    no                18261
#      sometimes          1366
#      when drinking      1162
#      yes                 796
#      trying to quit      480
# m    no                25635
#      sometimes          2421
#      when drinking      1878
#      yes                1435
#      trying to quit     1000
# Name: smokes, dtype: int64

# %%
lang=df1['speaks'].value_counts()
df=pd.set_option("display.max_rows", None)
print(lang)
# Out:
# sex  speaks
# f    english                                                                                                         9315
#      english (fluently)                                                                                              2466
#      english (fluently), spanish (okay)                                                                               852
#      english (fluently), spanish (poorly)                                                                             807
#      english (fluently), spanish (fluently)                                                                           535
#      english (fluently), french (poorly)                                                                              373
#      english, spanish                                                                                                 359
# ...

# %%
df1['status'].value_counts()
# Out:
# sex  status
# f    single            22319
#      seeing someone     1003
#      available           656
#      married             135
#      unknown               4
# m    single            33378
#      available          1209
#      seeing someone     1061
#      married             175
#      unknown               6
# Name: status, dtype: int64
